# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isla vista
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | fortuna
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | hami
# Processing Record 6 of Set 1 | fort nelson
# Processing Record 7 of Set 1 | namibe
# Processing Record 8 of Set 1 | hofn
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | ngaoundere
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | lolodorf
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | boa vista
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | dien bien
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | maningrida
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | pacific grove
# Processing Record 25 of Set 1 | palembang
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | sao joao da barra
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | flinders
# Processing Record 38 of Set 1 | hajnowka
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | fukue
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | anadyr
# Processing Record 45 of Set 1 | coquimbo
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | vrangel
# Processing Record 49 of Set 1 | gat
# Processing Record 50 of Set 1 | marystown
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | kaitong
# Processing Record 4 of Set 2 | nyagan
# Processing Record 5 of Set 2 | snezhnogorsk
# Processing Record 6 of Set 2 | suez
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | praya
# Processing Record 11 of Set 2 | cabedelo
# Processing Record 12 of Set 2 | akdepe
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | svarstad
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | broome
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | dingle
# Processing Record 22 of Set 2 | moctezuma
# Processing Record 23 of Set 2 | bugulma
# Processing Record 24 of Set 2 | prince rupert
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | baoro
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | punta arenas
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | college
# Processing Record 33 of Set 2 | tigil
# Processing Record 34 of Set 2 | samarai
# Processing Record 35 of Set 2 | port hardy
# Processing Record 36 of Set 2 | hambantota
# Processing Record 37 of Set 2 | tura
# Processing Record 38 of Set 2 | caraz
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | yumen
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | half moon bay
# Processing Record 44 of Set 2 | bichura
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | porto novo
# Processing Record 48 of Set 2 | neuquen
# Processing Record 49 of Set 2 | saint-joseph
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | liverpool
# Processing Record 2 of Set 3 | lhokseumawe
# Processing Record 3 of Set 3 | natal
# Processing Record 4 of Set 3 | hudson bay
# Processing Record 5 of Set 3 | saint-donat-de-montcalm
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | hare bay
# Processing Record 8 of Set 3 | port-gentil
# Processing Record 9 of Set 3 | tual
# Processing Record 10 of Set 3 | dordrecht
# Processing Record 11 of Set 3 | pontianak
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 3 | srednekolymsk
# Processing Record 15 of Set 3 | doka
# Processing Record 16 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 3 | marzuq
# Processing Record 18 of Set 3 | montrose
# Processing Record 19 of Set 3 | elizabeth city
# Processing Record 20 of Set 3 | nuuk
# Processing Record 21 of Set 3 | ulaanbaatar
# Processing Record 22 of Set 3 | pioner
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | mansa
# Processing Record 25 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | iturama
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | tiksi
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | esperance
# Processing Record 34 of Set 3 | houma
# Processing Record 35 of Set 3 | mookane
# Processing Record 36 of Set 3 | valday
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | clarence town
# Processing Record 39 of Set 3 | petrove
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | harlingen
# Processing Record 42 of Set 3 | faya
# Processing Record 43 of Set 3 | gombong
# Processing Record 44 of Set 3 | opuwo
# Processing Record 45 of Set 3 | myitkyina
# Processing Record 46 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 3 | vostok
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | ouricuri
# Processing Record 1 of Set 4 | laibin
# Processing Record 2 of Set 4 | kibala
# Processing Record 3 of Set 4 | saint-philippe
# Processing Record 4 of Set 4 | mayumba
# Processing Record 5 of Set 4 | taltal
# Processing Record 6 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 4 | srandakan
# Processing Record 8 of Set 4 | bajos de haina
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | nandu
# Processing Record 11 of Set 4 | hovd
# Processing Record 12 of Set 4 | naze
# Processing Record 13 of Set 4 | birao
# Processing Record 14 of Set 4 | kudahuvadhoo
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | petukhovo
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | mosetse
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 4 | pangnirtung
# Processing Record 27 of Set 4 | olafsvik
# Processing Record 28 of Set 4 | yenagoa
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | guilin
# Processing Record 31 of Set 4 | smithville
# Processing Record 32 of Set 4 | mirnyy
# Processing Record 33 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 4 | bagan
# Processing Record 35 of Set 4 | touros
# Processing Record 36 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | manavalakurichi
# Processing Record 39 of Set 4 | port lincoln
# Processing Record 40 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 4 | vzmorye
# Processing Record 42 of Set 4 | clovis
# Processing Record 43 of Set 4 | iquique
# Processing Record 44 of Set 4 | kirkkonummi
# Processing Record 45 of Set 4 | velikie luki
# City not found. Skipping...
# Processing Record 46 of Set 4 | aykhal
# Processing Record 47 of Set 4 | berlevag
# Processing Record 48 of Set 4 | orotukan
# Processing Record 49 of Set 4 | kenora
# Processing Record 50 of Set 4 | planaltina
# Processing Record 1 of Set 5 | tyup
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | mandalgovi
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | los llanos de aridane
# Processing Record 7 of Set 5 | mantoudion
# City not found. Skipping...
# Processing Record 8 of Set 5 | vigeland
# Processing Record 9 of Set 5 | saskylakh
# Processing Record 10 of Set 5 | east london
# Processing Record 11 of Set 5 | aripuana
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | san andres
# Processing Record 14 of Set 5 | souillac
# Processing Record 15 of Set 5 | camacha
# Processing Record 16 of Set 5 | pundaguitan
# Processing Record 17 of Set 5 | bengkulu
# Processing Record 18 of Set 5 | kangaatsiaq
# Processing Record 19 of Set 5 | sioux lookout
# Processing Record 20 of Set 5 | parbhani
# Processing Record 21 of Set 5 | husavik
# Processing Record 22 of Set 5 | nelson bay
# Processing Record 23 of Set 5 | namatanai
# Processing Record 24 of Set 5 | teahupoo
# Processing Record 25 of Set 5 | darnah
# Processing Record 26 of Set 5 | zholymbet
# Processing Record 27 of Set 5 | saint george
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | mokhotlong
# Processing Record 30 of Set 5 | sobolevo
# Processing Record 31 of Set 5 | mana
# Processing Record 32 of Set 5 | ponta do sol
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | umm kaddadah
# Processing Record 36 of Set 5 | hellvik
# Processing Record 37 of Set 5 | sayanogorsk
# Processing Record 38 of Set 5 | dillon
# Processing Record 39 of Set 5 | kozelsk
# Processing Record 40 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 5 | uribia
# Processing Record 42 of Set 5 | worthington
# Processing Record 43 of Set 5 | verkhnevilyuysk
# Processing Record 44 of Set 5 | goderich
# Processing Record 45 of Set 5 | casa grande
# Processing Record 46 of Set 5 | houston
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | krasnoselkup
# Processing Record 49 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | vao
# Processing Record 2 of Set 6 | carnarvon
# Processing Record 3 of Set 6 | ourossogui
# Processing Record 4 of Set 6 | nirmal
# Processing Record 5 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 6 | bathsheba
# Processing Record 7 of Set 6 | rio grande city
# Processing Record 8 of Set 6 | bitam
# Processing Record 9 of Set 6 | kurilsk
# Processing Record 10 of Set 6 | pontal do parana
# Processing Record 11 of Set 6 | rio grande
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | cap malheureux
# Processing Record 14 of Set 6 | jabinyanah
# Processing Record 15 of Set 6 | xixiang
# Processing Record 16 of Set 6 | kuching
# Processing Record 17 of Set 6 | asau
# Processing Record 18 of Set 6 | hamilton
# Processing Record 19 of Set 6 | mimarsinan
# Processing Record 20 of Set 6 | alamosa
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | soyo
# Processing Record 23 of Set 6 | nkowakowa
# Processing Record 24 of Set 6 | vestmanna
# Processing Record 25 of Set 6 | mandera
# Processing Record 26 of Set 6 | matara
# Processing Record 27 of Set 6 | gobabis
# Processing Record 28 of Set 6 | sovetskiy
# Processing Record 29 of Set 6 | kavaratti
# Processing Record 30 of Set 6 | clyde river
# Processing Record 31 of Set 6 | lompoc
# Processing Record 32 of Set 6 | raton
# Processing Record 33 of Set 6 | almeria
# Processing Record 34 of Set 6 | zhigansk
# Processing Record 35 of Set 6 | mudon
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | linxia
# Processing Record 38 of Set 6 | saint anthony
# Processing Record 39 of Set 6 | spring valley
# Processing Record 40 of Set 6 | santa maria
# Processing Record 41 of Set 6 | trairi
# Processing Record 42 of Set 6 | puerto madryn
# Processing Record 43 of Set 6 | tuktoyaktuk
# Processing Record 44 of Set 6 | coahuayana
# Processing Record 45 of Set 6 | balkanabat
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | altamont
# Processing Record 48 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 49 of Set 6 | rohnert park
# Processing Record 50 of Set 6 | georgetown
# Processing Record 1 of Set 7 | paducah
# Processing Record 2 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 7 | vanimo
# Processing Record 4 of Set 7 | apiai
# Processing Record 5 of Set 7 | aklavik
# Processing Record 6 of Set 7 | raudeberg
# Processing Record 7 of Set 7 | mwinilunga
# Processing Record 8 of Set 7 | sisimiut
# Processing Record 9 of Set 7 | nakamura
# Processing Record 10 of Set 7 | hualmay
# Processing Record 11 of Set 7 | fort myers beach
# Processing Record 12 of Set 7 | buraydah
# Processing Record 13 of Set 7 | krasnogorskoye
# Processing Record 14 of Set 7 | leningradskiy
# Processing Record 15 of Set 7 | kolo
# Processing Record 16 of Set 7 | port-de-bouc
# Processing Record 17 of Set 7 | atenas de san cristobal
# Processing Record 18 of Set 7 | batagay-alyta
# Processing Record 19 of Set 7 | karratha
# Processing Record 20 of Set 7 | olavarria
# Processing Record 21 of Set 7 | guaruja
# Processing Record 22 of Set 7 | ola
# Processing Record 23 of Set 7 | vilyuysk
# Processing Record 24 of Set 7 | alofi
# Processing Record 25 of Set 7 | hervey bay
# Processing Record 26 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 27 of Set 7 | okha
# Processing Record 28 of Set 7 | soloneshnoye
# Processing Record 29 of Set 7 | mbanza-ngungu
# Processing Record 30 of Set 7 | carutapera
# Processing Record 31 of Set 7 | netanya
# Processing Record 32 of Set 7 | kavieng
# Processing Record 33 of Set 7 | piotrkow trybunalski
# Processing Record 34 of Set 7 | camabatela
# Processing Record 35 of Set 7 | mercedes
# Processing Record 36 of Set 7 | filingue
# Processing Record 37 of Set 7 | kulhudhuffushi
# Processing Record 38 of Set 7 | victoria
# Processing Record 39 of Set 7 | gladstone
# Processing Record 40 of Set 7 | makakilo city
# Processing Record 41 of Set 7 | ixtapa
# Processing Record 42 of Set 7 | yizheng
# Processing Record 43 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 44 of Set 7 | kiunga
# Processing Record 45 of Set 7 | rovaniemi
# Processing Record 46 of Set 7 | oistins
# Processing Record 47 of Set 7 | bowen
# Processing Record 48 of Set 7 | nambucca heads
# Processing Record 49 of Set 7 | samokov
# Processing Record 50 of Set 7 | poum
# Processing Record 1 of Set 8 | sampit
# Processing Record 2 of Set 8 | lima
# Processing Record 3 of Set 8 | waitati
# Processing Record 4 of Set 8 | harper
# Processing Record 5 of Set 8 | zavodouspenskoye
# Processing Record 6 of Set 8 | biak
# Processing Record 7 of Set 8 | kenai
# Processing Record 8 of Set 8 | tecpan
# Processing Record 9 of Set 8 | ahipara
# Processing Record 10 of Set 8 | nouadhibou
# Processing Record 11 of Set 8 | pangkalanbuun
# Processing Record 12 of Set 8 | novobiryusinskiy
# Processing Record 13 of Set 8 | roald
# Processing Record 14 of Set 8 | aguada de pasajeros
# Processing Record 15 of Set 8 | basavana bagevadi
# Processing Record 16 of Set 8 | carndonagh
# Processing Record 17 of Set 8 | hasaki
# Processing Record 18 of Set 8 | kastrakion
# Processing Record 19 of Set 8 | pisco
# Processing Record 20 of Set 8 | luena
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | longkou
# Processing Record 23 of Set 8 | sola
# Processing Record 24 of Set 8 | barra
# Processing Record 25 of Set 8 | lobito
# Processing Record 26 of Set 8 | aswan
# Processing Record 27 of Set 8 | ormara
# Processing Record 28 of Set 8 | morondava
# Processing Record 29 of Set 8 | nabire
# Processing Record 30 of Set 8 | micheweni
# Processing Record 31 of Set 8 | santo antonio do sudoeste
# Processing Record 32 of Set 8 | ginda
# Processing Record 33 of Set 8 | pangody
# Processing Record 34 of Set 8 | lesnoye
# Processing Record 35 of Set 8 | bilma
# Processing Record 36 of Set 8 | avera
# Processing Record 37 of Set 8 | pingzhuang
# Processing Record 38 of Set 8 | albanel
# Processing Record 39 of Set 8 | jammalamadugu
# Processing Record 40 of Set 8 | xianshuigu
# Processing Record 41 of Set 8 | lata
# Processing Record 42 of Set 8 | ostrovnoy
# Processing Record 43 of Set 8 | dunhua
# Processing Record 44 of Set 8 | bozova
# Processing Record 45 of Set 8 | narok
# Processing Record 46 of Set 8 | hay river
# Processing Record 47 of Set 8 | vallenar
# Processing Record 48 of Set 8 | kloulklubed
# Processing Record 49 of Set 8 | turukhansk
# Processing Record 50 of Set 8 | kalaleh
# Processing Record 1 of Set 9 | rayagada
# Processing Record 2 of Set 9 | yarmouth
# Processing Record 3 of Set 9 | gisborne
# Processing Record 4 of Set 9 | zhetysay
# Processing Record 5 of Set 9 | miyakonojo
# Processing Record 6 of Set 9 | eureka
# Processing Record 7 of Set 9 | bud
# Processing Record 8 of Set 9 | mahanoro
# Processing Record 9 of Set 9 | clara
# Processing Record 10 of Set 9 | darhan
# Processing Record 11 of Set 9 | seoul
# Processing Record 12 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 9 | ostuacan
# Processing Record 14 of Set 9 | madinat sittah uktubar
# Processing Record 15 of Set 9 | mahbubabad
# Processing Record 16 of Set 9 | constitucion
# Processing Record 17 of Set 9 | dokka
# Processing Record 18 of Set 9 | adrar
# Processing Record 19 of Set 9 | hangu
# Processing Record 20 of Set 9 | aviles
# Processing Record 21 of Set 9 | altay
# Processing Record 22 of Set 9 | akureyri
# Processing Record 23 of Set 9 | axim
# Processing Record 24 of Set 9 | sakakah
# Processing Record 25 of Set 9 | cerro largo
# Processing Record 26 of Set 9 | gornopravdinsk
# Processing Record 27 of Set 9 | coihaique
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | tokoroa
# Processing Record 30 of Set 9 | leo
# Processing Record 31 of Set 9 | hilton head island
# Processing Record 32 of Set 9 | lunglei
# Processing Record 33 of Set 9 | smithers
# Processing Record 34 of Set 9 | adjumani
# Processing Record 35 of Set 9 | phanat nikhom
# Processing Record 36 of Set 9 | ossora
# Processing Record 37 of Set 9 | tombouctou
# Processing Record 38 of Set 9 | muros
# Processing Record 39 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 9 | noumea
# Processing Record 41 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 9 | burica
# City not found. Skipping...
# Processing Record 43 of Set 9 | yamethin
# Processing Record 44 of Set 9 | deer lake
# Processing Record 45 of Set 9 | soria
# Processing Record 46 of Set 9 | brisbane
# Processing Record 47 of Set 9 | lavumisa
# Processing Record 48 of Set 9 | sibu
# Processing Record 49 of Set 9 | quatre cocos
# Processing Record 50 of Set 9 | teya
# Processing Record 1 of Set 10 | quesnel
# Processing Record 2 of Set 10 | ekhabi
# Processing Record 3 of Set 10 | huarmey
# Processing Record 4 of Set 10 | trabzon
# Processing Record 5 of Set 10 | labuhan
# Processing Record 6 of Set 10 | farafangana
# Processing Record 7 of Set 10 | nadym
# Processing Record 8 of Set 10 | gumrak
# Processing Record 9 of Set 10 | chapais
# Processing Record 10 of Set 10 | lebu
# Processing Record 11 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 10 | sun city west
# Processing Record 13 of Set 10 | karasjok
# Processing Record 14 of Set 10 | erdemli
# Processing Record 15 of Set 10 | anchorage
# Processing Record 16 of Set 10 | tabou
# Processing Record 17 of Set 10 | aksarka
# Processing Record 18 of Set 10 | ravar
# Processing Record 19 of Set 10 | mizdah
# Processing Record 20 of Set 10 | laguna
# Processing Record 21 of Set 10 | emerald
# Processing Record 22 of Set 10 | palmares do sul
# Processing Record 23 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 10 | sri aman
# Processing Record 25 of Set 10 | sao lourenco do sul
# Processing Record 26 of Set 10 | arkhara
# Processing Record 27 of Set 10 | barreirinhas
# Processing Record 28 of Set 10 | monterey
# Processing Record 29 of Set 10 | male
# Processing Record 30 of Set 10 | salinas
# Processing Record 31 of Set 10 | lashio
# Processing Record 32 of Set 10 | santa rosa
# Processing Record 33 of Set 10 | kumluca
# Processing Record 34 of Set 10 | wyndham
# Processing Record 35 of Set 10 | saint-augustin
# Processing Record 36 of Set 10 | alta floresta
# Processing Record 37 of Set 10 | patawag
# Processing Record 38 of Set 10 | berbera
# Processing Record 39 of Set 10 | pilar
# Processing Record 40 of Set 10 | issaquah
# Processing Record 41 of Set 10 | meinerzhagen
# Processing Record 42 of Set 10 | komsomolskiy
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | amarante do maranhao
# Processing Record 45 of Set 10 | yulara
# Processing Record 46 of Set 10 | praia da vitoria
# Processing Record 47 of Set 10 | tateyama
# Processing Record 48 of Set 10 | fianga
# City not found. Skipping...
# Processing Record 49 of Set 10 | elat
# Processing Record 50 of Set 10 | haines junction
# Processing Record 1 of Set 11 | leshukonskoye
# Processing Record 2 of Set 11 | kostomuksha
# Processing Record 3 of Set 11 | moerai
# Processing Record 4 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 11 | nguruka
# Processing Record 6 of Set 11 | broken hill
# Processing Record 7 of Set 11 | paamiut
# Processing Record 8 of Set 11 | duzce
# Processing Record 9 of Set 11 | makung
# City not found. Skipping...
# Processing Record 10 of Set 11 | rocha
# Processing Record 11 of Set 11 | gamba
# Processing Record 12 of Set 11 | antalaha
# Processing Record 13 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 11 | cherskiy
# Processing Record 15 of Set 11 | wahiawa
# Processing Record 16 of Set 11 | henties bay
# Processing Record 17 of Set 11 | sukagawa
# Processing Record 18 of Set 11 | dunedin
# Processing Record 19 of Set 11 | hajipur
# Processing Record 20 of Set 11 | tepalcatepec
# Processing Record 21 of Set 11 | grand island
# Processing Record 22 of Set 11 | salym
# Processing Record 23 of Set 11 | vila velha
# Processing Record 24 of Set 11 | juneau
# Processing Record 25 of Set 11 | bonavista
# Processing Record 26 of Set 11 | maksatikha
# Processing Record 27 of Set 11 | kadoma
# Processing Record 28 of Set 11 | ingham
# Processing Record 29 of Set 11 | stange
# Processing Record 30 of Set 11 | necochea
# Processing Record 31 of Set 11 | chimbote
# Processing Record 32 of Set 11 | paysandu
# Processing Record 33 of Set 11 | doha
# Processing Record 34 of Set 11 | saurimo
# Processing Record 35 of Set 11 | mitu
# Processing Record 36 of Set 11 | anloga
# Processing Record 37 of Set 11 | sisophon
# Processing Record 38 of Set 11 | mount gambier
# Processing Record 39 of Set 11 | pangai
# Processing Record 40 of Set 11 | la paz
# Processing Record 41 of Set 11 | simbahan
# Processing Record 42 of Set 11 | lumajang
# Processing Record 43 of Set 11 | bako
# Processing Record 44 of Set 11 | velten
# Processing Record 45 of Set 11 | luanda
# Processing Record 46 of Set 11 | novokayakent
# Processing Record 47 of Set 11 | sena madureira
# Processing Record 48 of Set 11 | chalinze
# Processing Record 49 of Set 11 | livingston
# Processing Record 50 of Set 11 | malpe
# Processing Record 1 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 2 of Set 12 | aromashevo
# Processing Record 3 of Set 12 | moose factory
# Processing Record 4 of Set 12 | san quintin
# Processing Record 5 of Set 12 | gillette
# Processing Record 6 of Set 12 | guaraniacu
# Processing Record 7 of Set 12 | egvekinot
# Processing Record 8 of Set 12 | sibolga
# Processing Record 9 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 12 | bali chak
# Processing Record 11 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 12 | lethem
# Processing Record 13 of Set 12 | lancaster
# Processing Record 14 of Set 12 | galesong
# Processing Record 15 of Set 12 | geraldton
# Processing Record 16 of Set 12 | ahuimanu
# Processing Record 17 of Set 12 | ngunguru
# Processing Record 18 of Set 12 | russell
# Processing Record 19 of Set 12 | vestmannaeyjar
# Processing Record 20 of Set 12 | agirish
# Processing Record 21 of Set 12 | garowe
# Processing Record 22 of Set 12 | noyabrsk
# Processing Record 23 of Set 12 | puerto del rosario
# Processing Record 24 of Set 12 | liuhe
# Processing Record 25 of Set 12 | kropotkin
# Processing Record 26 of Set 12 | mezen
# Processing Record 27 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 28 of Set 12 | formosa
# Processing Record 29 of Set 12 | vila do maio
# Processing Record 30 of Set 12 | dolo
# Processing Record 31 of Set 12 | belaya gora
# Processing Record 32 of Set 12 | vicuna
# Processing Record 33 of Set 12 | pasinler
# Processing Record 34 of Set 12 | nakusp
# Processing Record 35 of Set 12 | zalantun
# Processing Record 36 of Set 12 | colwyn bay
# Processing Record 37 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 12 | terney
# Processing Record 39 of Set 12 | horsham
# Processing Record 40 of Set 12 | olinda
# Processing Record 41 of Set 12 | ilulissat
# Processing Record 42 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 12 | alamogordo
# Processing Record 44 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 12 | vengerovo
# Processing Record 46 of Set 12 | labayug
# Processing Record 47 of Set 12 | bubaque
# Processing Record 48 of Set 12 | koslan
# Processing Record 49 of Set 12 | garissa
# Processing Record 50 of Set 12 | saldanha
# Processing Record 1 of Set 13 | atasu
# Processing Record 2 of Set 13 | kushiro
# Processing Record 3 of Set 13 | san cristobal
# Processing Record 4 of Set 13 | drayton valley
# Processing Record 5 of Set 13 | dukat
# Processing Record 6 of Set 13 | xai-xai
# Processing Record 7 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 13 | salta
# Processing Record 9 of Set 13 | darayya
# Processing Record 10 of Set 13 | ca mau
# Processing Record 11 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 12 of Set 13 | along
# Processing Record 13 of Set 13 | kidal
# Processing Record 14 of Set 13 | west warwick
# Processing Record 15 of Set 13 | paramonga
# Processing Record 16 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 17 of Set 13 | lasa
# Processing Record 18 of Set 13 | mareeba
# Processing Record 19 of Set 13 | korla
# Processing Record 20 of Set 13 | timra
# Processing Record 21 of Set 13 | oeiras
# Processing Record 22 of Set 13 | xining
# Processing Record 23 of Set 13 | agadez
# Processing Record 24 of Set 13 | roma
# Processing Record 25 of Set 13 | palafrugell
# Processing Record 26 of Set 13 | parnamirim
# Processing Record 27 of Set 13 | tagusao
# Processing Record 28 of Set 13 | saint-louis
# Processing Record 29 of Set 13 | mulanay
# Processing Record 30 of Set 13 | ures
# Processing Record 31 of Set 13 | almenara
# Processing Record 32 of Set 13 | potsdam
# Processing Record 33 of Set 13 | dumai
# Processing Record 34 of Set 13 | arlit
# Processing Record 35 of Set 13 | opelousas
# Processing Record 36 of Set 13 | kapuskasing
# Processing Record 37 of Set 13 | marsaxlokk
# Processing Record 38 of Set 13 | puerto escondido
# Processing Record 39 of Set 13 | dwarka
# Processing Record 40 of Set 13 | tucupita
# Processing Record 41 of Set 13 | grand gaube
# Processing Record 42 of Set 13 | mastic beach
# Processing Record 43 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 13 | bereda
# Processing Record 45 of Set 13 | abu kamal
# Processing Record 46 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 13 | road town
# Processing Record 48 of Set 13 | vicksburg
# Processing Record 49 of Set 13 | mandalay
# Processing Record 50 of Set 13 | iqaluit
# Processing Record 1 of Set 14 | sao gabriel da cachoeira
# Processing Record 2 of Set 14 | mocuba
# Processing Record 3 of Set 14 | safaga
# Processing Record 4 of Set 14 | morales
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | gorkovskiy
# Processing Record 7 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 14 | port hedland
# Processing Record 10 of Set 14 | bukene
# Processing Record 11 of Set 14 | tabuk
# Processing Record 12 of Set 14 | ler
# Processing Record 13 of Set 14 | conceicao do araguaia
# Processing Record 14 of Set 14 | auki
# Processing Record 15 of Set 14 | forest grove
# Processing Record 16 of Set 14 | sao jose da coroa grande
# Processing Record 17 of Set 14 | praia
# Processing Record 18 of Set 14 | guerrero negro
# Processing Record 19 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 14 | jalu
# Processing Record 21 of Set 14 | tonantins
# Processing Record 22 of Set 14 | potgietersrus
# City not found. Skipping...
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | nizwa
# Processing Record 25 of Set 14 | la romana
# Processing Record 26 of Set 14 | turbat
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | kattivakkam
# Processing Record 29 of Set 14 | bell ville
# Processing Record 30 of Set 14 | moron
# Processing Record 31 of Set 14 | pontalina
# Processing Record 32 of Set 14 | la orilla
# Processing Record 33 of Set 14 | petrov val
# Processing Record 34 of Set 14 | pulandian
# Processing Record 35 of Set 14 | hirara
# Processing Record 36 of Set 14 | huallanca
# Processing Record 37 of Set 14 | cruden bay
# City not found. Skipping...
# Processing Record 38 of Set 14 | iskateley
# Processing Record 39 of Set 14 | yeppoon
# Processing Record 40 of Set 14 | valparaiso
# Processing Record 41 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 14 | khonsa
# Processing Record 43 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 14 | pemangkat
# Processing Record 45 of Set 14 | shar
# Processing Record 46 of Set 14 | bandarbeyla
# Processing Record 47 of Set 14 | sur
# Processing Record 48 of Set 14 | rio gallegos
# Processing Record 49 of Set 14 | awbari
# Processing Record 50 of Set 14 | gallup
# Processing Record 1 of Set 15 | vigrestad
# Processing Record 2 of Set 15 | comodoro rivadavia
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | ulaangom
# Processing Record 5 of Set 15 | fairbanks
# Processing Record 6 of Set 15 | puerto carreno
# Processing Record 7 of Set 15 | bac lieu
# Processing Record 8 of Set 15 | bilibino
# Processing Record 9 of Set 15 | khilok
# Processing Record 10 of Set 15 | svecha
# Processing Record 11 of Set 15 | aleksandrovskiy zavod
# Processing Record 12 of Set 15 | mehamn
# Processing Record 13 of Set 15 | mananjary
# Processing Record 14 of Set 15 | tukan
# Processing Record 15 of Set 15 | powell river
# Processing Record 16 of Set 15 | belize
# Processing Record 17 of Set 15 | languyan
# Processing Record 18 of Set 15 | hede
# Processing Record 19 of Set 15 | huixtla
# Processing Record 20 of Set 15 | aksu
# Processing Record 21 of Set 15 | ambilobe
# Processing Record 22 of Set 15 | popondetta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 666

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Isla Vista  34.4133 -119.8610     73.35        85           0
# 1  Mar Del Plata -38.0023  -57.5575     62.62        87           0
# 2        Fortuna  40.5982 -124.1573     52.36        89         100
# 3     Butaritari   3.0707  172.7902     81.70        68          41
# 4           Hami  42.8000   93.4500     72.43        14          56
# 5    Fort Nelson  58.8053 -122.7002     44.19        81          75
# 6         Namibe -15.1961   12.1522     72.23        78          75
# 7           Hofn  64.2539  -15.2082     46.56        84         100
# 8        Ushuaia -54.8000  -68.3000     40.62        75          40
# 9     Chokurdakh  70.6333  147.9167     32.86        73          81
#
#    Wind Speed Country                 Date Current Description
# 0        1.01      US  2022-09-17 14:52:25           clear sky
# 1       25.01      AR  2022-09-17 14:52:25           clear sky
# 2        2.15      US  2022-09-17 14:47:59     overcast clouds
# 3       11.95      KI  2022-09-17 14:52:26    scattered clouds
# 4        6.96      CN  2022-09-17 14:50:12       broken clouds
# 5        0.00      CA  2022-09-17 14:52:26       broken clouds
# 6       13.80      AO  2022-09-17 14:50:15       broken clouds
# 7        7.85      IS  2022-09-17 14:49:29     overcast clouds
# 8       24.16      AR  2022-09-17 14:49:41    scattered clouds
# 9        6.62      RU  2022-09-17 14:52:27       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Isla Vista      US  34.4133 -119.8610     73.35        85           0
# 1    Mar Del Plata      AR -38.0023  -57.5575     62.62        87           0
# 2          Fortuna      US  40.5982 -124.1573     52.36        89         100
# 3       Butaritari      KI   3.0707  172.7902     81.70        68          41
# 4             Hami      CN  42.8000   93.4500     72.43        14          56
# ..             ...     ...      ...       ...       ...       ...         ...
# 661           Hede      CN  33.7681  120.2517     69.03        94           2
# 662        Huixtla      MX  15.1500  -92.4667     80.28        77          87
# 663           Aksu      CN  41.1231   80.2644     78.13        22         100
# 664       Ambilobe      MG -13.2000   49.0500     77.00        51          46
# 665     Popondetta      PG  -8.7537  148.2534     72.25        96          83
#
#      Wind Speed Current Description
# 0          1.01           clear sky
# 1         25.01           clear sky
# 2          2.15     overcast clouds
# 3         11.95    scattered clouds
# 4          6.96       broken clouds
# ..          ...                 ...
# 661        5.86           clear sky
# 662        1.90     overcast clouds
# 663        1.90     overcast clouds
# 664        3.56    scattered clouds
# 665        3.24       broken clouds
#
# [666 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
